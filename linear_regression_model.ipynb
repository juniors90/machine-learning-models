# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import joblib

# %%
df=pd.read_csv('dataset/Linear_regression_dataset.csv',header='infer')
df.sample(5)
# Out:
#       var_1  var_2  var_3  var_4  var_5  output
# 365     764    904     65  0.335  0.256   0.411
# 997     754    561     97  0.345  0.266   0.389
# 119     710    874     59  0.337  0.258   0.406
# 1183    737    678     79  0.322  0.252   0.427
# 527     707    806     75  0.335  0.267   0.393

# %%
X=df.loc[:,df.columns !='output']
y=df['output']
lr = LinearRegression().fit(X, y)
lr.score(X,y)
# Out:
# 0.8692670151914199

# %%
joblib.dump(lr,'linear_regression_model.pkl')
# Out:
# ['linear_regression_model.pkl']

# %%
lr.coef_
# Out:
# array([ 3.40469932e-04,  5.28843636e-05,  1.88543327e-04, -6.57578433e-01,
#         4.97636500e-01])

# %%
lr.intercept_
# Out:
# 0.18637196667060477

# %%
lr.predict(np.array([[3, 5, 3, 4, 9]]))
# Out:
# array([2.0366382])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
X.shape
# Out:
# (1232, 5)

# %%
x_axis = list(range(X.shape[0]))
y_axis = y

fig, ax = plt.subplots()
ax.plot(x_axis,y_axis, '-')
fig.set_size_inches(20,7)
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style='ticks')
sns.pairplot(X)

# %%
sns.violinplot(x=df['var_1'], y=df['var_3'])
# Out:
# <AxesSubplot:xlabel='var_1', ylabel='var_3'>

# %%
del lr

# %%
lr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-653612280959> in <module>
# ----> 1 lr
#
# NameError: name 'lr' is not defined
